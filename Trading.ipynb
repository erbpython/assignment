# %% [markdown]
# **Install pandas**

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /Users/user1/.pyenv/versions/3.14.2/lib/python3.14/site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in /Users/user1/.pyenv/versions/3.14.2/lib/python3.14/site-packages (from pandas) (2.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/user1/.pyenv/versions/3.14.2/lib/python3.14/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/user1/.pyenv/versions/3.14.2/lib/python3.14/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/user1/.pyenv/versions/3.14.2/lib/python3.14/site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in /Users/user1/.pyenv/versions/3.14.2/lib/python3.14/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
#  **Load the raw datas**

# %%
import pandas as pd

customers = pd.read_csv("customers_dirty.csv")
products = pd.read_csv("products_dirty.csv")
trades = pd.read_csv("trades_dirty.csv")

# %% [markdown]
# **Inspecting the data**

# %%
customers.head(),
customers.info()
customers.isnull().sum()
print()
products.head()
products.info()
products.isnull().sum()
print()
trades.head()
trades.info()
trades.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CustomerID    30 non-null     object
#  1   CustomerName  30 non-null     object
#  2   Country       30 non-null     object
#  3   City          30 non-null     object
#  4   Email         25 non-null     object
#  5   Phone         30 non-null     object
# dtypes: object(6)
# memory usage: 1.5+ KB
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ProductID      30 non-null     object
#  1   ProductName    23 non-null     object
#  2   Category       24 non-null     object
#  3   UnitOfMeasure  30 non-null     object
#  4   StandardCost   18 non-null     float64
#  5   ListPrice      21 non-null     float64
#  6   Currency       30 non-null     object
#  7   OriginCountry  19 non-null     object
# dtypes: float64(2), object(6)
# memory usage: 2.0+ KB
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TradeID      30 non-null     object
#  1   BuyerID      30 non-null     object
#  2   SellerID     30 non-null     object
#  3   ProductID    30 non-null     object
#  4   Quantity     21 non-null     float64
#  5   UnitPrice    17 non-null     float64
#  6   TradeValue   0 non-null      float64
#  7   TradeStatus  30 non-null     object
#  8   Currency     30 non-null     object
# dtypes: float64(3), object(6)
# memory usage: 2.2+ KB
# TradeID         0
# BuyerID         0
# SellerID        0
# ProductID       0
# Quantity        9
# UnitPrice      13
# TradeValue     30
# TradeStatus     0
# Currency        0
# dtype: int64

# %% [markdown]
# **Remove Duplicate Records**

# %%
customers = customers.drop_duplicates()
products = products.drop_duplicates()
trades = trades.drop_duplicates()

# %% [markdown]
# **Format or Standardize the Fields**

# %%
products["UnitOfMeasure"] = products["UnitOfMeasure"].str.upper()
products["Currency"] = products["Currency"].str.upper()
trades["Currency"] = trades["Currency"].str.upper()

# %% [markdown]
# **Handle Missing (NULL) Values**

# %%
customers["CustomerName"] = customers["CustomerName"].fillna("Unknown")
customers["Email"] = customers["Email"].fillna("not_provided@tradeco.com")
customers["Country"] = customers["Country"].fillna("Unknown")
products["ProductName"] = products["ProductName"].fillna("Undefined")
products["Category"] = products["Category"].fillna("Other")
products["StandardCost"] = products["StandardCost"].fillna(products["StandardCost"].median())
products["ListPrice"] = products["ListPrice"].fillna(products["ListPrice"].median())
products["OriginCountry"] = products["OriginCountry"].fillna("Unknown")
trades["Quantity"] = trades["Quantity"].fillna(trades["Quantity"].median())
trades["UnitPrice"] = trades["UnitPrice"].fillna(trades["UnitPrice"].median())

# %% [markdown]
# **Recalculate Derived Fields (TradeValue)**

# %%
trades["TradeValue"] = trades["Quantity"]* trades["UnitPrice"]

# %% [markdown]
# **Validate Referential Integrity (Foreign Keys)**

# %%
valid_customers = set(customers["CustomerID"])
valid_products = set(products["ProductID"])

trades = trades[
    trades["BuyerID"].isin(valid_customers) &
    trades["SellerID"].isin(valid_customers) &
    trades["ProductID"].isin(valid_products)
]

# %% [markdown]
# **Final Data Quality Checks**

# %%
#customers.isnull().sum()
#products.isnull().sum()
trades.isnull().sum()
# Out:
# TradeID        0
# BuyerID        0
# SellerID       0
# ProductID      0
# Quantity       0
# UnitPrice      0
# TradeValue     0
# TradeStatus    0
# Currency       0
# dtype: int64

# %% [markdown]
# **Save Cleaned Datasets**

# %%
customers.to_csv("customers_clean.csv", index=False)
products.to_csv("products_clean.csv", index=False)
trades.to_csv("trades_clean.csv", index=False)
